# %% [markdown]
# ## Importções e leitura dos stats

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open(r"matrix_multiplication\data\stats.json", "r", encoding="utf8") as f:
    data = json.load(f)

# Records 1: Linear e paralelo
# Records 2: Distribuido
records = []
records_2 = []

for entry in data:
    for key, value in entry.items():
        value["type"] = key
        records.append(value)

df = pd.DataFrame(records)
df.head()
# Out:
#    time_seconds  num_cores  block_size           type  num_servers  \
# 0    739.016216        1.0        4096         Linear          NaN
# 1    128.502636        1.0         128  Blocked local          NaN
# 2     72.352800        2.0         128  Blocked local          NaN
# 3     42.954266        4.0         128  Blocked local          NaN
# 4     35.033347        6.0         128  Blocked local          NaN
#
#    backend_block_size compression
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN

# %% [markdown]
# ## Gráficos Comparativos

# %% [markdown]
# #### Grafíco das execuções paralelas locais usando o algoritmo de multiplicação de blocos

# %%
# Filtrar apenas execuções "Blocked local"
df_blocked = df[df['type'] == 'Blocked local'].copy()

# %%
plt.figure(figsize=(8,5))
for block_size, subdf in df_blocked.groupby("block_size"):
    plt.plot(subdf["num_cores"], subdf["time_seconds"], marker='o', label=f"Block {block_size}")
plt.xlabel("Número de núcleos")
plt.ylabel("Tempo de execução (s)")
plt.title("Tempo de execução parelelo por número de núcleos e tamanho de bloco")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Tempo linear (base)
T1 = df[df['type'] == 'Linear']['time_seconds'].iloc[0]
T2 = df[(df['type'] == 'Blocked local') & (df['block_size'] == 128)]['time_seconds'].iloc[0]
T3 = df[(df['type'] == 'Blocked local') & (df['block_size'] == 256)]['time_seconds'].iloc[0]
T4 = df[(df['type'] == 'Blocked local') & (df['block_size'] == 512)]['time_seconds'].iloc[0]

print(T1)
print(T2)

# Calcular speedup e eficiência
df_blocked["speedup"] = T2 / df_blocked["time_seconds"]
df_blocked["efficiency"] = df_blocked["speedup"] / df_blocked["num_cores"]

df_blocked
# Out:
# 739.0162164000212
# 128.50263569998788
#     time_seconds  num_cores  block_size           type  num_servers  \
# 1     128.502636        1.0         128  Blocked local          NaN
# 2      72.352800        2.0         128  Blocked local          NaN
# 3      42.954266        4.0         128  Blocked local          NaN
# 4      35.033347        6.0         128  Blocked local          NaN
# 5      30.545650        8.0         128  Blocked local          NaN
# 6      29.067674       10.0         128  Blocked local          NaN
# 7      27.808154       12.0         128  Blocked local          NaN
# 8     118.307509        1.0         256  Blocked local          NaN
# 9      72.965026        2.0         256  Blocked local          NaN
# 10     49.395249        4.0         256  Blocked local          NaN
# 11     37.935167        6.0         256  Blocked local          NaN
# 12     31.553169        8.0         256  Blocked local          NaN
# 13     28.631263       10.0         256  Blocked local          NaN
# 14     30.043067       12.0         256  Blocked local          NaN
# 15    112.326914        1.0         512  Blocked local          NaN
# 16     95.600444        2.0         512  Blocked local          NaN
# 17     51.219795        4.0         512  Blocked local          NaN
# 18     44.656620        6.0         512  Blocked local          NaN
# 19     35.967005        8.0         512  Blocked local          NaN
# 20     36.653248       10.0         512  Blocked local          NaN
# 21     37.590372       12.0         512  Blocked local          NaN
#
#     backend_block_size compression   speedup  efficiency
# 1                  NaN         NaN  1.000000    1.000000
# 2                  NaN         NaN  1.776056    0.888028
# 3                  NaN         NaN  2.991615    0.747904
# 4                  NaN         NaN  3.668009    0.611335
# 5                  NaN         NaN  4.206905    0.525863
# 6                  NaN         NaN  4.420809    0.442081
# 7                  NaN         NaN  4.621042    0.385087
# 8                  NaN         NaN  1.086175    1.086175
# 9                  NaN         NaN  1.761154    0.880577
# 10                 NaN         NaN  2.601518    0.650380
# 11                 NaN         NaN  3.387428    0.564571
# 12                 NaN         NaN  4.072575    0.509072
# 13                 NaN         NaN  4.488193    0.448819
# 14                 NaN         NaN  4.277281    0.356440
# 15                 NaN         NaN  1.144006    1.144006
# 16                 NaN         NaN  1.344164    0.672082
# 17                 NaN         NaN  2.508847    0.627212
# 18                 NaN         NaN  2.877572    0.479595
# 19                 NaN         NaN  3.572792    0.446599
# 20                 NaN         NaN  3.505900    0.350590
# 21                 NaN         NaN  3.418499    0.284875

# %%
plt.figure(figsize=(8,5))
for block_size, subdf in df_blocked.groupby("block_size"):
    plt.plot(subdf["num_cores"], subdf["speedup"], marker='o', label=f"Block {block_size}")
plt.xlabel("Número de núcleos")
plt.ylabel("Speedup")
plt.title("Speedup por número de núcleos")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
for block_size, subdf in df_blocked.groupby("block_size"):
    plt.plot(subdf["num_cores"], subdf["efficiency"], marker='o', label=f"Block {block_size}")
plt.xlabel("Número de núcleos")
plt.ylabel("Eficiência")
plt.title("Eficiência por número de núcleos")
plt.legend()
plt.grid(True)
plt.show()

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# === 1️⃣ Ler os dados ===
with open(r"matrix_multiplication\data\stats.json", "r") as f:
    data = json.load(f)

records = []
for entry in data:
    for key, value in entry.items():
        value["type"] = key
        records.append(value)

df = pd.DataFrame(records)

# === 2️⃣ Extrair tempos relevantes ===
T_linear = df.loc[df['type'] == 'Linear', 'time_seconds'].iloc[0]
T_distributed = df.loc[df['type'] == 'Distributed', 'time_seconds'].iloc[0]

# Filtrar execuções locais bloqueadas
df_blocked = df[df['type'] == 'Blocked local'].copy()

# Calcular speedup e eficiência relativos ao linear
df_blocked["speedup"] = T_linear / df_blocked["time_seconds"]
df_blocked["efficiency"] = df_blocked["speedup"] / df_blocked["num_cores"]

# === 3️⃣ Criar DataFrame com linha do distribuído ===
distributed_row = pd.DataFrame([{
    "type": "Distributed",
    "time_seconds": T_distributed,
    "num_cores": df_blocked["num_cores"].max(),  # ou outro valor simbólico (ex: 12)
    "block_size": 2048,
    "speedup": T_linear / T_distributed,
    "efficiency": (T_linear / T_distributed) / df_blocked["num_cores"].max()
}])

# Juntar tudo
df_all = pd.concat([df_blocked, distributed_row], ignore_index=True)

# === 4️⃣ Gráfico 1: Tempo comparando local e distribuído ===
plt.figure(figsize=(9,5))
for block_size, subdf in df_blocked.groupby("block_size"):
    plt.plot(subdf["num_cores"], subdf["time_seconds"], marker='o', label=f"Local block {block_size}")

plt.axhline(T_distributed, color="green", linestyle="--", label=f"Distributed ({T_distributed:.1f}s)")
plt.scatter([12], [T_distributed], color="green", s=80, zorder=5)

plt.title("Tempo de execução — Local vs Distribuído")
plt.xlabel("Número de núcleos")
plt.ylabel("Tempo (s)")
plt.legend()
plt.grid(True)
plt.show()

# === 5️⃣ Gráfico 2: Speedup comparando local e distribuído ===
plt.figure(figsize=(9,5))
for block_size, subdf in df_blocked.groupby("block_size"):
    plt.plot(subdf["num_cores"], subdf["speedup"], marker='o', label=f"Local block {block_size}")

plt.axhline(T_linear / T_distributed, color="green", linestyle="--", label=f"Distributed (S = {T_linear / T_distributed:.2f})")
plt.scatter([12], [T_linear / T_distributed], color="green", s=80, zorder=5)

plt.title("Speedup — Local vs Distribuído")
plt.xlabel("Número de núcleos")
plt.ylabel("Speedup")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Cálculo do Speedup

# %% [markdown]
# ## Cálculo da Eficiência

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# -------------------------------------
# 1. Ler o arquivo JSON
# -------------------------------------
with open("matrix_multiplication\data\stats.json", "r") as f:
    data = json.load(f)

# -------------------------------------
# 2. Normalizar em um DataFrame
# -------------------------------------
records = []
for entry in data:
    for key, val in entry.items():
        record = val.copy()
        record["type"] = key
        records.append(record)

df = pd.DataFrame(records)

# Normalizar colunas ausentes
for col in ["num_cores", "num_servers", "block_size"]:
    if col not in df.columns:
        df[col] = None

df["num_cores"] = df["num_cores"].fillna(df["num_servers"])
df = df.drop(columns=["num_servers"], errors="ignore")

df = df.sort_values(["type", "block_size", "num_cores"]).reset_index(drop=True)

print("=== TABELA ORIGINAL ===")
print(df[["type", "num_cores", "block_size", "time_seconds"]])

# -------------------------------------
# 3. Identificar casos base
# -------------------------------------
t1_linear = df.loc[df["type"] == "Linear", "time_seconds"].values[0]
t1_blocked128 = df.loc[
    (df["type"] == "Blocked local") & (df["block_size"] == 128) & (df["num_cores"] == 1),
    "time_seconds",
].values[0]

# -------------------------------------
# 4. Calcular métricas
# -------------------------------------
def compute_metrics(df, base_time):
    df = df.copy()
    df["speedup"] = base_time / df["time_seconds"]
    df["efficiency"] = df["speedup"] / df["num_cores"]
    df["redundancy"] = (df["time_seconds"] * df["num_cores"]) / base_time
    return df

df_linear_base = compute_metrics(df, t1_linear)
df_block128_base = compute_metrics(df, t1_blocked128)

# -------------------------------------
# 5. Exportar CSV resumo
# -------------------------------------
df_out = df_linear_base[[
    "type", "num_cores", "block_size", "time_seconds",
    "speedup", "efficiency", "redundancy"
]]
df_out.to_csv("results_summary.csv", index=False)
print("\n✅ Resultados exportados para results_summary.csv")

# -------------------------------------
# 6. Tabelas resumidas no console
# -------------------------------------
def summary_table(df, label):
    print(f"\n=== MÉTRICAS USANDO BASE: {label} ===")
    print(
        df[["type", "num_cores", "block_size", "time_seconds", "speedup", "efficiency", "redundancy"]]
        .round(3)
        .to_string(index=False)
    )

summary_table(df_linear_base, "Linear")
summary_table(df_block128_base, "Blocked local 128")

# -------------------------------------
# 7. Gráficos comparativos
# -------------------------------------
def plot_metric(df, metric, base_label, filter_type=None):
    plt.figure(figsize=(8, 5))
    if filter_type:
        df = df[df["type"] == filter_type]

    for bsize in sorted(df["block_size"].dropna().unique()):
        subset = df[(df["block_size"] == bsize) & (df["num_cores"].notna())]
        if not subset.empty:
            plt.plot(subset["num_cores"], subset[metric], marker="o", label=f"Block {int(bsize)}")

    plt.title(f"{metric.capitalize()} vs Núcleos ({base_label})" + (f" — {filter_type}" if filter_type else ""))
    plt.xlabel("Número de núcleos")
    plt.ylabel(metric.capitalize())
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig(f"{metric}_{base_label.replace(' ', '_')}_{filter_type or 'all'}.png", dpi=150)
    plt.show()

# Comparação geral (todos os tipos)
for metric in ["speedup", "efficiency", "redundancy"]:
    plot_metric(df_linear_base, metric, "Linear base")
    plot_metric(df_linear_base, metric, "Linear base", "Blocked local")
    plot_metric(df_linear_base, metric, "Linear base", "Distributed")

# -------------------------------------
# 8. Gráfico dos tempos de execução absolutos
# -------------------------------------
plt.figure(figsize=(9, 5))
for bsize in sorted(df["block_size"].dropna().unique()):
    subset = df[(df["type"] == "Blocked local") & (df["block_size"] == bsize)]
    if not subset.empty:
        plt.plot(subset["num_cores"], subset["time_seconds"], marker="o", label=f"Blocked {int(bsize)}")

dist = df[df["type"] == "Distributed"]
if not dist.empty:
    plt.plot(dist["num_cores"], dist["time_seconds"], marker="s", linestyle="--", label="Distributed")

linear = df[df["type"] == "Linear"]
if not linear.empty:
    plt.scatter([1], [linear["time_seconds"].values[0]], color="red", label="Linear", zorder=5)

plt.title("Tempo de execução (segundos) por tipo e número de núcleos")
plt.xlabel("Número de núcleos")
plt.ylabel("Tempo (s)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("execution_times.png", dpi=150)
plt.show()
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\bruno\AppData\Local\Temp\ipykernel_21408\2978935322.py:8: SyntaxWarning: invalid escape sequence '\d'
#   with open("matrix_multiplication\data\stats.json", "r") as f:
# === TABELA ORIGINAL ===
#              type  num_cores  block_size  time_seconds
# 0   Blocked local        1.0         128    128.502636
# 1   Blocked local        2.0         128     72.352800
# 2   Blocked local        4.0         128     42.954266
# 3   Blocked local        6.0         128     35.033347
# 4   Blocked local        8.0         128     30.545650
# 5   Blocked local       10.0         128     29.067674
# 6   Blocked local       12.0         128     27.808154
# 7   Blocked local        1.0         256    118.307509
# 8   Blocked local        2.0         256     72.965026
# 9   Blocked local        4.0         256     49.395249
# 10  Blocked local        6.0         256     37.935167
# 11  Blocked local        8.0         256     31.553169
# 12  Blocked local       10.0         256     28.631263
# 13  Blocked local       12.0         256     30.043067
# 14  Blocked local        1.0         512    112.326914
# 15  Blocked local        2.0         512     95.600444
# 16  Blocked local        4.0         512     51.219795
# 17  Blocked local        6.0         512     44.656620
# 18  Blocked local        8.0         512     35.967005
# 19  Blocked local       10.0         512     36.653248
# 20  Blocked local       12.0         512     37.590372
# 21    Distributed        1.0        2048     48.786262
# 22    Distributed        1.0        2048     46.570898
# 23    Distributed        2.0        2048    120.386793
# 24         Linear        1.0        4096    739.016216
#
# ✅ Resultados exportados para results_summary.csv
#
# === MÉTRICAS USANDO BASE: Linear ===
#          type  num_cores  block_size  time_seconds  speedup  efficiency  redundancy
# Blocked local        1.0         128       128.503    5.751       5.751       0.174
# Blocked local        2.0         128        72.353   10.214       5.107       0.196
# Blocked local        4.0         128        42.954   17.205       4.301       0.232
# Blocked local        6.0         128        35.033   21.095       3.516       0.284
# Blocked local        8.0         128        30.546   24.194       3.024       0.331
# Blocked local       10.0         128        29.068   25.424       2.542       0.393
# Blocked local       12.0         128        27.808   26.576       2.215       0.452
# Blocked local        1.0         256       118.308    6.247       6.247       0.160
# Blocked local        2.0         256        72.965   10.128       5.064       0.197
# Blocked local        4.0         256        49.395   14.961       3.740       0.267
# Blocked local        6.0         256        37.935   19.481       3.247       0.308
# Blocked local        8.0         256        31.553   23.421       2.928       0.342
# Blocked local       10.0         256        28.631   25.812       2.581       0.387
# Blocked local       12.0         256        30.043   24.599       2.050       0.488
# Blocked local        1.0         512       112.327    6.579       6.579       0.152
# Blocked local        2.0         512        95.600    7.730       3.865       0.259
# Blocked local        4.0         512        51.220   14.428       3.607       0.277
# Blocked local        6.0         512        44.657   16.549       2.758       0.363
# Blocked local        8.0         512        35.967   20.547       2.568       0.389
# Blocked local       10.0         512        36.653   20.162       2.016       0.496
# Blocked local       12.0         512        37.590   19.660       1.638       0.610
#   Distributed        1.0        2048        48.786   15.148      15.148       0.066
#   Distributed        1.0        2048        46.571   15.869      15.869       0.063
#   Distributed        2.0        2048       120.387    6.139       3.069       0.326
#        Linear        1.0        4096       739.016    1.000       1.000       1.000
#
# === MÉTRICAS USANDO BASE: Blocked local 128 ===
#          type  num_cores  block_size  time_seconds  speedup  efficiency  redundancy
# Blocked local        1.0         128       128.503    1.000       1.000       1.000
# Blocked local        2.0         128        72.353    1.776       0.888       1.126
# Blocked local        4.0         128        42.954    2.992       0.748       1.337
# Blocked local        6.0         128        35.033    3.668       0.611       1.636
# Blocked local        8.0         128        30.546    4.207       0.526       1.902
# Blocked local       10.0         128        29.068    4.421       0.442       2.262
# Blocked local       12.0         128        27.808    4.621       0.385       2.597
# Blocked local        1.0         256       118.308    1.086       1.086       0.921
# Blocked local        2.0         256        72.965    1.761       0.881       1.136
# Blocked local        4.0         256        49.395    2.602       0.650       1.538
# Blocked local        6.0         256        37.935    3.387       0.565       1.771
# Blocked local        8.0         256        31.553    4.073       0.509       1.964
# Blocked local       10.0         256        28.631    4.488       0.449       2.228
# Blocked local       12.0         256        30.043    4.277       0.356       2.806
# Blocked local        1.0         512       112.327    1.144       1.144       0.874
# Blocked local        2.0         512        95.600    1.344       0.672       1.488
# Blocked local        4.0         512        51.220    2.509       0.627       1.594
# Blocked local        6.0         512        44.657    2.878       0.480       2.085
# Blocked local        8.0         512        35.967    3.573       0.447       2.239
# Blocked local       10.0         512        36.653    3.506       0.351       2.852
# Blocked local       12.0         512        37.590    3.418       0.285       3.510
#   Distributed        1.0        2048        48.786    2.634       2.634       0.380
#   Distributed        1.0        2048        46.571    2.759       2.759       0.362
#   Distributed        2.0        2048       120.387    1.067       0.534       1.874
#        Linear        1.0        4096       739.016    0.174       0.174       5.751
